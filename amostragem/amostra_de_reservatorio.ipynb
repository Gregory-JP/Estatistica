# %%
import pandas as pd
import random

# %%
df = pd.read_csv('../bases_dados/census.csv')

# %%
stream = []

for i in range(len(df)):
    stream.append(i)

# %%
def amostragem_reservatorio(df, amostras):
    stream = []
    
    for i in range(len(df)):
        stream.append(i)
    
    i = 0
    tamanho = len(df)
    
    reservatorio = [0] * amostras
    
    for i in range(amostras):
        reservatorio[i] = stream[i]
        
    while i < tamanho:
        j = random.randrange(i + 1)
        
        if j < amostras:
            reservatorio[j] = stream[i]
        
        i += 1
    return df.iloc[reservatorio]

# %%
df_amostragem_reservatorio = amostragem_reservatorio(df, 100)
df_amostragem_reservatorio.shape
# Out:
# (100, 15)

# %%
df_amostragem_reservatorio.head()
# Out:
#        age workclass  final-weight      education  education-num  \
# 11491   30   Private        222162        HS-grad              9
# 13597   40   Private         69333      Bachelors             13
# 21299   24   Private        192201   Some-college             10
# 19532   27   Private        133929      Bachelors             13
# 9644    18   Private        238401   Some-college             10
#
#             marital-status          occupation    relationship    race  \
# 11491   Married-civ-spouse   Handlers-cleaners         Husband   White
# 13597   Married-civ-spouse     Farming-fishing         Husband   White
# 21299        Never-married     Exec-managerial   Not-in-family   Black
# 19532        Never-married      Prof-specialty       Unmarried   White
# 9644         Never-married               Sales       Own-child   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 11491     Male             0             0             66   United-States
# 13597     Male             0             0             40   United-States
# 21299   Female             0             0             20   United-States
# 19532   Female             0             0             36               ?
# 9644    Female             0             0             25   United-States
#
#        income
# 11491   <=50K
# 13597   <=50K
# 21299   <=50K
# 19532   <=50K
# 9644    <=50K
