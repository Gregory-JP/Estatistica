# %%
from scipy.stats import gamma
import seaborn as sns

# %%
dados_gamma = gamma.rvs(a=1, size=1000)

# %%
dados_gamma.shape
# Out:
# (1000,)

# %%
sns.displot(dados_gamma, kde=True);

# %%
min(dados_gamma), max(dados_gamma)
# Out:
# (3.692866239110939e-05, 8.046608262542643)
