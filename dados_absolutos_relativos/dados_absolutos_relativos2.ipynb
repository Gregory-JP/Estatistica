# %%
import pandas as pd

# %%
df = pd.read_csv('../bases_dados/census.csv')

# %%
df
# Out:
#        age          workclass  final-weight    education  education-num  \
# 0       39          State-gov         77516    Bachelors             13
# 1       50   Self-emp-not-inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
df2 = df[['education', 'income']]
df2
# Out:
#          education  income
# 0        Bachelors   <=50K
# 1        Bachelors   <=50K
# 2          HS-grad   <=50K
# 3             11th   <=50K
# 4        Bachelors   <=50K
# ...            ...     ...
# 32556   Assoc-acdm   <=50K
# 32557      HS-grad    >50K
# 32558      HS-grad   <=50K
# 32559      HS-grad   <=50K
# 32560      HS-grad    >50K
#
# [32561 rows x 2 columns]

# %%
df3 = df.groupby(['education', 'income'])['education'].count()

# %%
df3
# Out:
# education      income
#  10th           <=50K     871
#                 >50K       62
#  11th           <=50K    1115
#                 >50K       60
#  12th           <=50K     400
#                 >50K       33
#  1st-4th        <=50K     162
#                 >50K        6
#  5th-6th        <=50K     317
#                 >50K       16
#  7th-8th        <=50K     606
#                 >50K       40
#  9th            <=50K     487
#                 >50K       27
#  Assoc-acdm     <=50K     802
#                 >50K      265
#  Assoc-voc      <=50K    1021
#                 >50K      361
#  Bachelors      <=50K    3134
#                 >50K     2221
#  Doctorate      <=50K     107
#                 >50K      306
#  HS-grad        <=50K    8826
#                 >50K     1675
#  Masters        <=50K     764
#                 >50K      959
#  Preschool      <=50K      51
#  Prof-school    <=50K     153
#                 >50K      423
#  Some-college   <=50K    5904
# ...

# %%
df3[' Bachelors', ' <=50K'], df3[' Bachelors', ' >50K']
# Out:
# (3134, 2221)

# %%
3134 + 2221
# Out:
# 5355

# %%
# % >50K
(2221 / 5355) * 100
# Out:
# 41.47525676937442

# %%
# % <=50K
(3134 / 5355) * 100
# Out:
# 58.52474323062559
